# %%
import pandas as pd

# %%
#reading our main dataset
housing_data=pd.read_csv("Melbourne_housing_FULL.csv")
housing_data.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
#get the list of columns titles
housing_data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
#Number of rows and columns
housing_data.shape
# Out:
# (34857, 21)

# %%
#check number of values for each title
housing_data.count()
# Out:
# Suburb           34857
# Address          34857
# Rooms            34857
# Type             34857
# Price            27247
# Method           34857
# SellerG          34857
# Date             34857
# Distance         34856
# Postcode         34856
# Bedroom2         26640
# Bathroom         26631
# Car              26129
# Landsize         23047
# BuildingArea     13742
# YearBuilt        15551
# CouncilArea      34854
# Lattitude        26881
# Longtitude       26881
# Regionname       34854
# Propertycount    34854
# dtype: int64

# %%
# droo NAN values from the dataset and clean our dataset
housing_cleaned_data=housing_data.dropna()
housing_cleaned_data.count()
# Out:
# Suburb           8887
# Address          8887
# Rooms            8887
# Type             8887
# Price            8887
# Method           8887
# SellerG          8887
# Date             8887
# Distance         8887
# Postcode         8887
# Bedroom2         8887
# Bathroom         8887
# Car              8887
# Landsize         8887
# BuildingArea     8887
# YearBuilt        8887
# CouncilArea      8887
# Lattitude        8887
# Longtitude       8887
# Regionname       8887
# Propertycount    8887
# dtype: int64

# %%
#check types of values 
housing_cleaned_data.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
#convert postcode type from float to ineteger and then object for getting it ready to merge. 
convert_types={"Postcode" : int}
housing_cleaned_data=housing_cleaned_data.astype(convert_types)
convert_types={"Postcode" : object , "Price": int , "Propertycount" : int ,
               "Bedroom2" : int, "Bathroom" : int , "Car" : int , "YearBuilt" : int , "Landsize" : int,
               "BuildingArea": int, "Propertycount" : int}
housing_cleaned_data=housing_cleaned_data.astype(convert_types)

# %%
housing_cleaned_data.head()
# Out:
#         Suburb          Address  Rooms Type    Price Method SellerG  \
# 2   Abbotsford  25 Bloomburg St      2    h  1035000      S  Biggin
# 4   Abbotsford     5 Charles St      3    h  1465000     SP  Biggin
# 6   Abbotsford      55a Park St      4    h  1600000     VB  Nelson
# 11  Abbotsford     124 Yarra St      3    h  1876000      S  Nelson
# 14  Abbotsford    98 Charles St      2    h  1636000      S  Nelson
#
#          Date  Distance Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 2   4/02/2016       2.5     3067  ...         1    0       156            79
# 4   4/03/2017       2.5     3067  ...         2    0       134           150
# 6   4/06/2016       2.5     3067  ...         1    2       120           142
# 11  7/05/2016       2.5     3067  ...         2    0       245           210
# 14  8/10/2016       2.5     3067  ...         1    2       256           107
#
#     YearBuilt         CouncilArea Lattitude  Longtitude  \
# ...

# %%
#save housing_data to csv file
housing_cleaned_data.to_csv("cleaned_housing_data.csv", encoding="utf-8", index=False)

# %%
housing_cleaned_data.set_index("Postcode")
# Out:
#               Suburb           Address  Rooms Type    Price Method  SellerG  \
# Postcode
# 3067      Abbotsford   25 Bloomburg St      2    h  1035000      S   Biggin
# 3067      Abbotsford      5 Charles St      3    h  1465000     SP   Biggin
# 3067      Abbotsford       55a Park St      4    h  1600000     VB   Nelson
# 3067      Abbotsford      124 Yarra St      3    h  1876000      S   Nelson
# 3067      Abbotsford     98 Charles St      2    h  1636000      S   Nelson
# ...              ...               ...    ...  ...      ...    ...      ...
# 3750         Wollert   27 Birchmore Rd      3    h   500000     PI      Ray
# 3750         Wollert   35 Kingscote Wy      3    h   570000     SP       RW
# 3013      Yarraville     29A Murray St      2    h   888000     SP  Sweeney
# 3013      Yarraville    147A Severn St      2    t   705000      S      Jas
# 3013      Yarraville  3 Tarrengower St      2    h  1020000     PI       RW
#
# ...

# %%
#import Census data
census_data=pd.read_csv("../VIC/2021Census_G02_VIC_POA.csv")
census_data.head()
# Out:
#   POA_CODE_2021  Median_age_persons  Median_mortgage_repay_monthly  \
# 0       POA3000                  28                           1733
# 1       POA3002                  42                           2383
# 2       POA3003                  31                           2106
# 3       POA3004                  37                           2000
# 4       POA3006                  31                           1900
#
#    Median_tot_prsnl_inc_weekly  Median_rent_weekly  Median_tot_fam_inc_weekly  \
# 0                          768                 370                       1857
# 1                         1532                 480                       3733
# 2                         1058                 388                       2406
# 3                         1343                 451                       2727
# 4                         1171                 411                       2450
#
#    Average_num_psns_per_bedroom  Median_tot_hhd_inc_weekly  \
# ...

# %%
census_data.columns
# Out:
# Index(['POA_CODE_2021', 'Median_age_persons', 'Median_mortgage_repay_monthly',
#        'Median_tot_prsnl_inc_weekly', 'Median_rent_weekly',
#        'Median_tot_fam_inc_weekly', 'Average_num_psns_per_bedroom',
#        'Median_tot_hhd_inc_weekly', 'Average_household_size'],
#       dtype='object')

# %%
#change postcode column title and type and removing POA from the postcode
census_data["POA_CODE_2021"]=census_data["POA_CODE_2021"].str.replace('POA', '')
census_data=census_data.rename(columns={"POA_CODE_2021": "Postcode" })
convert_types={"Postcode" : object}
census_data=census_data.astype(convert_types)
census_data.dtypes
# Out:
# Postcode                          object
# Median_age_persons                 int64
# Median_mortgage_repay_monthly      int64
# Median_tot_prsnl_inc_weekly        int64
# Median_rent_weekly                 int64
# Median_tot_fam_inc_weekly          int64
# Average_num_psns_per_bedroom     float64
# Median_tot_hhd_inc_weekly          int64
# Average_household_size           float64
# dtype: object

# %%
#save cleaned census dataset to csv file
census_data.to_csv("census.csv", encoding="utf-8", index=False)

# %%
census_data.set_index("Postcode")
# Out:
#           Median_age_persons  Median_mortgage_repay_monthly  \
# Postcode
# 3000                      28                           1733
# 3002                      42                           2383
# 3003                      31                           2106
# 3004                      37                           2000
# 3006                      31                           1900
# ...                      ...                            ...
# 3990                      56                           2134
# 3991                      49                           1500
# 3992                      43                           1517
# 3995                      50                           1300
# 3996                      54                           1700
#
#           Median_tot_prsnl_inc_weekly  Median_rent_weekly  \
# Postcode
# 3000                              768                 370
# 3002                             1532                 480
# ...

# %%
housing_census_df=pd.merge(left=housing_cleaned_data, right=census_data , left_index=True, right_index=True , how="inner")
housing_census_df.count()
# Out:
# Suburb                           242
# Address                          242
# Rooms                            242
# Type                             242
# Price                            242
# Method                           242
# SellerG                          242
# Date                             242
# Distance                         242
# Postcode_x                       242
# Bedroom2                         242
# Bathroom                         242
# Car                              242
# Landsize                         242
# BuildingArea                     242
# YearBuilt                        242
# CouncilArea                      242
# Lattitude                        242
# Longtitude                       242
# Regionname                       242
# Propertycount                    242
# Postcode_y                       242
# Median_age_persons               242
# Median_mortgage_repay_monthly    242
# Median_tot_prsnl_inc_weekly      242
# ...

# %%
housing_census_df.head()
# Out:
#         Suburb          Address  Rooms Type    Price Method SellerG  \
# 2   Abbotsford  25 Bloomburg St      2    h  1035000      S  Biggin
# 4   Abbotsford     5 Charles St      3    h  1465000     SP  Biggin
# 6   Abbotsford      55a Park St      4    h  1600000     VB  Nelson
# 11  Abbotsford     124 Yarra St      3    h  1876000      S  Nelson
# 14  Abbotsford    98 Charles St      2    h  1636000      S  Nelson
#
#          Date  Distance Postcode_x  ...  Propertycount  Postcode_y  \
# 2   4/02/2016       2.5       3067  ...           4019        3003
# 4   4/03/2017       2.5       3067  ...           4019        3006
# 6   4/06/2016       2.5       3067  ...           4019        3011
# 11  7/05/2016       2.5       3067  ...           4019        3018
# 14  8/10/2016       2.5       3067  ...           4019        3021
#
#     Median_age_persons  Median_mortgage_repay_monthly  \
# 2                   31                           2106
# ...
