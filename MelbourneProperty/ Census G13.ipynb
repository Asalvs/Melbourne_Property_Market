# %%
import pandas as pd

# %%
census_G13_data=pd.read_csv("../VIC/2021Census_G13A_VIC_POA.csv")
census_G13_data.head()
# Out:
#   POA_CODE_2021  MSEO_SEO MSEO_UOLSE_VWorW MSEO_UOLSE_NWorNAA MSEO_UOLSE_Tot  \
# 0       POA3000      7433               ..                 ..             ..
# 1       POA3002      1905               ..                 ..             ..
# 2       POA3003      2026               ..                 ..             ..
# 3       POA3004      3347               ..                 ..             ..
# 4       POA3006      5622               ..                 ..             ..
#
#   MSEO_NS  MSEO_Tot MOL_Afrikaans_SEO  MOL_Afrikaans_UOLSE_VWorW  \
# 0      ..      7433                ..                         10
# 1      ..      1905                ..                          6
# 2      ..      2026                ..                          0
# 3      ..      3347                ..                          9
# 4      ..      5622                ..                          8
#
#    MOL_Afrikaans_UOLSE_NWorNAA  ...  MOL_Samoan_NS  MOL_Samoan_Tot  \
# ...

# %%
census_G13_data["POA_CODE_2021"]=census_data["POA_CODE_2021"].str.replace('POA', '')

# %%
census_G13_data.columns
# Out:
# Index(['POA_CODE_2021', 'MSEO_SEO', 'MSEO_UOLSE_VWorW', 'MSEO_UOLSE_NWorNAA',
#        'MSEO_UOLSE_Tot', 'MSEO_NS', 'MSEO_Tot', 'MOL_Afrikaans_SEO',
#        'MOL_Afrikaans_UOLSE_VWorW', 'MOL_Afrikaans_UOLSE_NWorNAA',
#        ...
#        'MOL_Samoan_NS', 'MOL_Samoan_Tot', 'MOL_Serbian_SEO',
#        'MOL_Serbian_UOLSE_VWorW', 'MOL_Serbian_UOLSE_NWorNAA',
#        'MOL_Serbian_UOLSE_Tot', 'MOL_Serbian_NS', 'MOL_Serbian_Tot',
#        'MOL_SAL_Filipin_SEO', 'MOL_SAL_Filipin_UOLSE_VWorW'],
#       dtype='object', length=201)

# %%
census_G13_data.to_csv("censusG13.csv", encoding="utf-8", index=False)
