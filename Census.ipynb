# %%
import pandas as pd

# %%
census_data=pd.read_csv("../VIC/2021Census_G01_VIC_POA.csv")
census_data.head()
# Out:
#   POA_CODE_2021  Tot_P_M  Tot_P_F  Tot_P_P  Age_0_4_yr_M  Age_0_4_yr_F  \
# 0       POA3000    21548    21539    43084           347           345
# 1       POA3002     2353     2545     4896            59            53
# 2       POA3003     4093     3926     8025           118           137
# 3       POA3004     5655     5827    11482           168           193
# 4       POA3006    11499    11197    22699           365           332
#
#    Age_0_4_yr_P  Age_5_14_yr_M  Age_5_14_yr_F  Age_5_14_yr_P  ...  \
# 0           697            388            376            767  ...
# 1           110             87             91            176  ...
# 2           250            167            167            336  ...
# 3           362            224            223            448  ...
# 4           702            333            326            657  ...
#
#    High_yr_schl_comp_Yr_8_belw_P  High_yr_schl_comp_D_n_g_sch_M  \
# 0                            287                            155
# ...

# %%
census_data["POA_CODE_2021"]=census_data["POA_CODE_2021"].str.replace('POA', '')

# %%
census_data
# Out:
#     POA_CODE_2021  Tot_P_M  Tot_P_F  Tot_P_P  Age_0_4_yr_M  Age_0_4_yr_F  \
# 0            3000    21548    21539    43084           347           345
# 1            3002     2353     2545     4896            59            53
# 2            3003     4093     3926     8025           118           137
# 3            3004     5655     5827    11482           168           193
# 4            3006    11499    11197    22699           365           332
# ..            ...      ...      ...      ...           ...           ...
# 689          3990       55       62      118             0             3
# 690          3991      204      205      405            10            11
# 691          3992      650      631     1281            37            29
# 692          3995     5588     6009    11596           238           244
# 693          3996     3194     3453     6649           150           162
#
#      Age_0_4_yr_P  Age_5_14_yr_M  Age_5_14_yr_F  Age_5_14_yr_P  ...  \
# ...
